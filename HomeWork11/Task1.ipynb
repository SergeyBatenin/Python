# %%
"""f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

Определить корни

Найти интервалы, на которых функция возрастает

Найти интервалы, на которых функция убывает

Построить график

Вычислить вершину

Определить промежутки, на котором f > 0

Определить промежутки, на котором f < 0
"""
# Out:
# 'f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30\n\nОпределить корни\n\nНайти интервалы, на которых функция возрастает\n\nНайти интервалы, на которых функция убывает\n\nПостроить график\n\nВычислить вершину\n\nОпределить промежутки, на котором f > 0\n\nОпределить промежутки, на котором f < 0\n'

# %%
import matplotlib.pyplot as plt

# %%
i = list(range(-200, 200))
f = [-12 * sin(cos(x)) * x ** 4 - 18 * x ** 3 + 5 * x ** 2 + 10 * x - 30 for x in i]

# %%
plt.plot(i, f)
plt.show()

# %%
solve(f, x) #Бесконечное множество корней, 
# а так же интервалов где функция возрастает/убывает. И Интервалов где функция больше/меньше 0
# Out:
# []
